# %% [markdown]
# ## Imorting Pandas & Introduction

# %%
import pandas as pd

# %%
students_dict = {
    'Names' : ['John', 'Adam', 'Steve', 'Sara'],
    'Homeworks Grades' : [72, 86, 91, 88],
    'Final Exam Grades' : [89, 97, 92, 94]
}

# %%
students_df = pd.DataFrame(students_dict)

# %%
students_df
# Out:
#    Names  Homeworks Grades  Final Exam Grades
# 0   John                72                 89
# 1   Adam                86                 97
# 2  Steve                91                 92
# 3   Sara                88                 94

# %%
students_df.shape
# Out:
# (4, 3)

# %%
students_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Names              4 non-null      object
#  1   Homeworks Grades   4 non-null      int64
#  2   Final Exam Grades  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
students_df.describe()
# Out:
#        Homeworks Grades  Final Exam Grades
# count          4.000000           4.000000
# mean          84.250000          93.000000
# std            8.421203           3.366502
# min           72.000000          89.000000
# 25%           82.500000          91.250000
# 50%           87.000000          93.000000
# 75%           88.750000          94.750000
# max           91.000000          97.000000

# %% [markdown]
# ## Getting introductry info about a real data

# %%
data = pd.read_csv('E:/Downloads/titanic.csv')

# %% [markdown]
# --- Download this dataset from the link below:
# https://drive.google.com/file/d/11t7CTQ4EMe1GbcmEbbPdEwFYnGSPyzup/view?usp=sharing

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                          Name  \
# count    891.000000  891.000000  891.000000                           891
# unique          NaN         NaN         NaN                           891
# top             NaN         NaN         NaN  Jacobsohn, Mr. Sidney Samuel
# freq            NaN         NaN         NaN                             1
# mean     446.000000    0.383838    2.308642                           NaN
# std      257.353842    0.486592    0.836071                           NaN
# min        1.000000    0.000000    1.000000                           NaN
# 25%      223.500000    0.000000    2.000000                           NaN
# 50%      446.000000    0.000000    3.000000                           NaN
# 75%      668.500000    1.000000    3.000000                           NaN
# max      891.000000    1.000000    3.000000                           NaN
#
#          Sex         Age       SibSp       Parch    Ticket        Fare  \
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.sample(8)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 273          274         0       1              Natsch, Mr. Charles H    male
# 492          493         0       1         Molson, Mr. Harry Markland    male
# 536          537         0       1  Butt, Major. Archibald Willingham    male
# 205          206         0       3         Strom, Miss. Telma Matilda  female
# 226          227         1       2          Mellors, Mr. William John    male
# 587          588         1       1   Frolicher-Stehli, Mr. Maxmillian    male
# 12            13         0       3     Saundercock, Mr. William Henry    male
# 55            56         1       1                  Woolner, Mr. Hugh    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 273  37.0      0      1   PC 17596  29.7000  C118        C
# 492  55.0      0      0     113787  30.5000   C30        S
# 536  45.0      0      0     113050  26.5500   B38        S
# ...
