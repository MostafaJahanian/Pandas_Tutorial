# %%
import pandas as pd

# %%
data = pd.read_csv('E:/Downloads/Titanic.csv')

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 1

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### 2

# %%
data.set_index('Sex', inplace = True)
data
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# male              1         0       3
# female            2         1       1
# female            3         1       3
# female            4         1       1
# male              5         0       3
# ...             ...       ...     ...
# male            887         0       2
# female          888         1       1
# female          889         0       3
# male            890         1       1
# male            891         0       3
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# male                              Braund, Mr. Owen Harris  22.0      1      0
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female                             Heikkinen, Miss. Laina  26.0      0      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# male                             Allen, Mr. William Henry  35.0      0      0
# ...

# %%
data.loc['male', ['Fare', 'Age']].describe()
# Out:
#              Fare         Age
# count  577.000000  453.000000
# mean    25.523893   30.726645
# std     43.138263   14.678201
# min      0.000000    0.420000
# 25%      7.895800   21.000000
# 50%     10.500000   29.000000
# 75%     26.550000   39.000000
# max    512.329200   80.000000

# %%
data.loc['female', ['Fare', 'Age']].describe()
# Out:
#              Fare         Age
# count  314.000000  261.000000
# mean    44.479818   27.915709
# std     57.997698   14.110146
# min      6.750000    0.750000
# 25%     12.071875   18.000000
# 50%     23.000000   27.000000
# 75%     55.000000   37.000000
# max    512.329200   63.000000

# %% [markdown]
# ### 3

# %%
data.reset_index(inplace = True)
data
# Out:
#         Sex  PassengerId  Survived  Pclass  \
# 0      male            1         0       3
# 1    female            2         1       1
# 2    female            3         1       3
# 3    female            4         1       1
# 4      male            5         0       3
# ..      ...          ...       ...     ...
# 886    male          887         0       2
# 887  female          888         1       1
# 888  female          889         0       3
# 889    male          890         1       1
# 890    male          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...
