# %% [markdown]
# ## Importing Pandas and DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv('E:/Downloads/Titanic.csv')

# %% [markdown]
# ## Separating Columns - 1

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.columns[2]
# Out:
# 'Pclass'

# %%
data['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Pclass'].describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: Pclass, dtype: float64

# %%
data['Ticket'].head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %%
data[['Fare', 'Cabin']]
# Out:
#         Fare Cabin
# 0     7.2500   NaN
# 1    71.2833   C85
# 2     7.9250   NaN
# 3    53.1000  C123
# 4     8.0500   NaN
# ..       ...   ...
# 886  13.0000   NaN
# 887  30.0000   B42
# 888  23.4500   NaN
# 889  30.0000  C148
# 890   7.7500   NaN
#
# [891 rows x 2 columns]

# %%
data[data.columns[-1]]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# ## Separating Columns - 2

# %%
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data.Age.tail()
# Out:
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Indexes - *set_index*

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.set_index('PassengerId', inplace = True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.set_index(keys = ['Name', 'Pclass'])
# Out:
#                                                            Survived     Sex  \
# Name                                               Pclass
# Braund, Mr. Owen Harris                            3              0    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha... 1              1  female
# Heikkinen, Miss. Laina                             3              1  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1              1  female
# Allen, Mr. William Henry                           3              0    male
# ...                                                             ...     ...
# Montvila, Rev. Juozas                              2              0    male
# Graham, Miss. Margaret Edith                       1              1  female
# Johnston, Miss. Catherine Helen "Carrie"           3              0  female
# Behr, Mr. Karl Howell                              1              1    male
# Dooley, Mr. Patrick                                3              0    male
# ...

# %%
data.set_index('Age', drop = False)
# Out:
#       Survived  Pclass                                               Name  \
# Age
# 22.0         0       3                            Braund, Mr. Owen Harris
# 38.0         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 26.0         1       3                             Heikkinen, Miss. Laina
# 35.0         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 35.0         0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 27.0         0       2                              Montvila, Rev. Juozas
# 19.0         1       1                       Graham, Miss. Margaret Edith
# NaN          0       3           Johnston, Miss. Catherine Helen "Carrie"
# 26.0         1       1                              Behr, Mr. Karl Howell
# 32.0         0       3                                Dooley, Mr. Patrick
#
#          Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.set_index('Name', inplace = True, append = True)

# %%
data
# Out:
#                                                                 Survived  \
# PassengerId Name
# 1           Braund, Mr. Owen Harris                                    0
# 2           Cumings, Mrs. John Bradley (Florence Briggs Tha...         1
# 3           Heikkinen, Miss. Laina                                     1
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)               1
# 5           Allen, Mr. William Henry                                   0
# ...                                                                  ...
# 887         Montvila, Rev. Juozas                                      0
# 888         Graham, Miss. Margaret Edith                               1
# 889         Johnston, Miss. Catherine Helen "Carrie"                   0
# 890         Behr, Mr. Karl Howell                                      1
# 891         Dooley, Mr. Patrick                                        0
#
#                                                                 Pclass  \
# ...

# %% [markdown]
# ## Indexes - *reset_index*

# %%
data.reset_index()
# Out:
#      PassengerId                                               Name  Survived  \
# 0              1                            Braund, Mr. Owen Harris         0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2              3                             Heikkinen, Miss. Laina         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4              5                           Allen, Mr. William Henry         0
# ..           ...                                                ...       ...
# 886          887                              Montvila, Rev. Juozas         0
# 887          888                       Graham, Miss. Margaret Edith         1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"         0
# 889          890                              Behr, Mr. Karl Howell         1
# 890          891                                Dooley, Mr. Patrick         0
#
# ...

# %%
data.reset_index(drop = True)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# ...

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#      PassengerId                                               Name  Survived  \
# 0              1                            Braund, Mr. Owen Harris         0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2              3                             Heikkinen, Miss. Laina         1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4              5                           Allen, Mr. William Henry         0
# ..           ...                                                ...       ...
# 886          887                              Montvila, Rev. Juozas         0
# 887          888                       Graham, Miss. Margaret Edith         1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"         0
# 889          890                              Behr, Mr. Karl Howell         1
# 890          891                                Dooley, Mr. Patrick         0
#
# ...

# %% [markdown]
# ## Separating Rows & Columns - *loc*

# %%
data.loc[92, 'Ticket']
# Out:
# 'W.E.P. 5734'

# %%
data.loc[[8, 45, 63], ['Name', 'Age']]
# Out:
#                                                  Name   Age
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 45                           Rogers, Mr. William John   NaN
# 63                              Skoog, Master. Harald   4.0

# %%
data.loc[54:70:3, ['Pclass', 'Fare']]
# Out:
#     Pclass     Fare
# 54       1  61.9792
# 57       3   7.2292
# 60       3   7.2292
# 63       3  27.9000
# 66       2  10.5000
# 69       3   8.6625

# %%
data.loc[[38, 92], 'Pclass':'Embarked':2]
# Out:
#     Pclass   Age  Parch    Fare Embarked
# 38       3  18.0      0  18.000        S
# 92       1  46.0      0  61.175        S

# %%
data.loc[:, 'Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
data.set_index('Sex', inplace = True)

# %%
data.loc['male', 'Fare']
# Out:
# Sex
# male     7.2500
# male     8.0500
# male     8.4583
# male    51.8625
# male    21.0750
#          ...
# male    10.5000
# male     7.0500
# male    13.0000
# male    30.0000
# male     7.7500
# Name: Fare, Length: 577, dtype: float64

# %%
data.reset_index(inplace = True)
data.set_index('Age', inplace = True)

# %%
data.loc[22.0, 'Name']
# Out:
# Age
# 22.0                              Braund, Mr. Owen Harris
# 22.0                                Sirayanian, Mr. Orsen
# 22.0                                 Waelens, Mr. Achille
# 22.0                               Barton, Mr. David John
# 22.0                             Nysten, Miss. Anna Sofia
# 22.0                    Pears, Mrs. Thomas (Edith Wearne)
# 22.0                               Perkin, Mr. John Henry
# 22.0                         Berglund, Mr. Karl Ivar Sven
# 22.0                        Maenpaa, Mr. Matti Alexanteri
# 22.0                                 Naidenoff, Mr. Penko
# 22.0                                 Connolly, Miss. Kate
# 22.0                                   Dennis, Mr. Samuel
# 22.0    Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...
# 22.0                          Bowerman, Miss. Elsie Edith
# 22.0                                  Ringhini, Mr. Sante
# 22.0                      Landergren, Miss. Aurora Adelia
# ...

# %% [markdown]
# ## Separating Rows and Columns - *iloc*

# %%
data.reset_index(inplace = True)

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'PassengerId', 'Name', 'Survived', 'Pclass', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.iloc[68, 0]
# Out:
# 17.0

# %%
data.iloc[[42, 57], 1:6:2]
# Out:
#      Sex                 Name  Pclass
# 42  male  Kraeff, Mr. Theodor       3
# 57  male  Novel, Mr. Mansouer       3
